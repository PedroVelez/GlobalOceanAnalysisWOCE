# %%
from ReadOriginalData import *

# %% [markdown]
# ### Plot all the sections of a given directory

# %%
#:param path: directory
#:param dst_path: directory for figures to be saved
#:param projection: cartopy projection
#:param central_long: central longitude of the projection
#:param copy: boolean to indicate if files are copied to dst_path
#:param start_secction: section str where user wants to start, default -> A01
    
path="Data/corrected_sections/"
dst_path="Data/corrected_sections_plots/"
projection = ccrs.PlateCarree
central_long=0
start_section = "A01"

# %%
colors = ["b", "g", "r", "c", "m", "y", "k", "peru", "lime", "slategrey", "yellowgreen", "hotpink","b", "g", "r", "c", "m", "y", "k", "peru", "lime", "slategrey", "yellowgreen", "hotpink"]

# %%
sections = sorted(os.listdir(path)) # sorted sections
index_start = sections.index(start_section) # Start section

# %%
sections
# Out:
# ['.DS_Store',
#  '.gitkeep',
#  'A01',
#  'A02',
#  'A05',
#  'A10',
#  'A12',
#  'A13.5',
#  'A16',
#  'A20',
#  'A22',
#  'I03',
#  'I04',
#  'I05',
#  'I06',
#  'I08',
#  'I09S',
#  'P01',
#  'P02',
#  'P03',
#  'P06',
#  'P10',
#  'P14',
#  'P15',
#  'P16',
#  'P17',
#  'P18',
#  'P21',
#  'S04',
#  'SR03']

# %%
# Crear la carpeta padre si no existe
os.makedirs(dst_path, exist_ok=True)

# %%
for section in sections[index_start:]:

    print(f"Plotting section {section}....")
    save_path = f"{dst_path}{section}/" # Path for save the files

    fig = plt.figure(figsize=(12, 10))
    ax = plt.axes(projection=projection())
    
    # Create if that path does not exist
    if os.path.exists(save_path) == False: os.mkdir(save_path)
    
    # Iterate over all the files in path
    for i, f in enumerate(os.listdir(path + section + "/")):
        f_path = path + section + "/" + f # File path
        nombre = f.split(".")[0] # File name

        if f_path.endswith('.nc'):
            ds = xr.load_dataset(f_path) # Open dataset
            # Create and plot the figure

            # Add features 
            #ax = plt.axes(projection = projection(central_longitude = 180 if str(section[0]) == "I" or str(section[0]) == "P" else 0))
            
            # Scatter of points
            ax.scatter(ds.longitude, ds.latitude, marker = ".", color = colors[i], label = f"{f}", transform = projection())

    # Save files
    
    ax.set_extent((-180, 180, -90, 90))
    ax.gridlines(draw_labels=True, linewidth=1, color='gray', alpha=0.4, linestyle='--')
    ax.coastlines()
    plt.title(f"Section {section}" )
    plt.legend()
    plt.savefig(f"{save_path}section_{section}.png")
    print("Done!")
# Out:
# Plotting section A01....
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# Done!
# Plotting section A02....
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# Done!
# Plotting section A05....
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# Done!
# Plotting section A10....
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# Done!
# Plotting section A12....
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# Done!
# Plotting section A13.5....
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# Done!
# Plotting section A16....
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# Done!
# Plotting section A20....
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# Done!
# Plotting section A22....
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# Done!
# Plotting section I03....
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# Done!
# Plotting section I04....
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# Done!
# Plotting section I05....
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# Done!
# Plotting section I06....
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# Done!
# Plotting section I08....
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# Done!
# Plotting section I09S....
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# Done!
# Plotting section P01....
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# Done!
# Plotting section P02....
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# Done!
# Plotting section P03....
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# Done!
# Plotting section P06....
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# Done!
# Plotting section P10....
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /var/folders/42/87g0dc1x415_cxhxy_ywklt80000gn/T/ipykernel_3050/1297602366.py:6: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig = plt.figure(figsize=(12, 10))
# Done!
# Plotting section P14....
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# Done!
# Plotting section P15....
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# Done!
# Plotting section P16....
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# Done!
# Plotting section P17....
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# Done!
# Plotting section P18....
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# Done!
# Plotting section P21....
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# Done!
# Plotting section S04....
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# Done!
# Plotting section SR03....
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# Done!
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /Users/pvb/miniconda3/envs/ocean/lib/python3.14/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
