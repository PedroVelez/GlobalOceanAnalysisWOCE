# %%
from ReadOriginalData import *

# %% [markdown]
# ### Características previas

# %%
#data: csv file with data (Required "Sección" and "Año" columns)
# dst_path" directory for figure to be saved
data = "./Data/data.csv"
dst_path = "./Data/"

# %% [markdown]
# ## Plot occupation of sections over years

# %%
# Open csv file
df = pd.read_csv(data, quotechar='"')

# %%
df
# Out:
#                                                   File Section  Year     Ref  \
# 0    ./Data/corrected_sections/A01\1991_06MT18_1_ct...     A01  1991  ITS-90
# 1    ./Data/corrected_sections/A01\1994_06MT30_3_ct...     A01  1994       0
# 2    ./Data/corrected_sections/A01\1995_18HU95011_1...     A01  1995  ITS-90
# 3    ./Data/corrected_sections/A01\2000_64PE2000092...     A01  2000  ITS-90
# 4    ./Data/corrected_sections/A01\2000_64PE2000092...     A01  2000  ITS-90
# ..                                                 ...     ...   ...     ...
# 247  ./Data/corrected_sections/SR03\2007_2008_09AR2...    SR03  2008  ITS-90
# 248  ./Data/corrected_sections/SR03\2008_09AR200803...    SR03  2008  ITS-90
# 249  ./Data/corrected_sections/SR03\2011_09AR201101...    SR03  2011  ITS-90
# 250  ./Data/corrected_sections/SR03\2017_3206201704...    SR03  2017  ITS-90
# 251  ./Data/corrected_sections/SR03\2018_096U201801...    SR03  2018  ITS-90
#
#                                                Comment
# 0                                                   0
# 1                                                   0
# 2                                                   0
# 3    Shared with AR07, but section_id = [A1E/AR7E],...
# 4                                                   0
# ..                                                 ...
# 247                                                 0
# 248                                                 0
# 249                                                 0
# 250                                                 0
# 251                                                 0
#
# [252 rows x 5 columns]

# %%
fig = plt.figure(figsize = (5, 10))

# Get years and sections
years = df["Year"][::-1]
sections = df["Section"][::-1]

# Plot
plt.plot(years, sections, ".k")

# Add features
plt.xlabel("Years")
plt.grid()

# Save the figure
plt.savefig(f"{dst_path}oceanOccupation.png")
