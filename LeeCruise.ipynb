# %% [markdown]
# #

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
import tqdm as tqdm
import pickle
import glob

from ReadOriginalData import vars_coords_interest

# %% [markdown]
# Vamos a leer todos los archivos, y vamos a quedarnos con el número total de N_LEVELS y N_PROF. De forma que para cada variable tendremos un array N_PROF x N_LEVELS (En el caso del archivo con la presión interpolada, será N_PROF x max(presion_interp)).
#
# Nos quedaremos con datos importantes como el section_id, latitud y longitud, fecha, y nombre del archivo para cada perfil, entre otros.

# %%
path = "./Data/corrected_sections_filtrado/A05/1992_29HE06_1_ctd.nc"
path='./Data/join/total_filt.nc'

# %%
DS=xr.open_dataset(path)

# %%
DS
# Out:
# <xarray.Dataset> Size: 3GB
# Dimensions:               (N_PROF: 17157, P: 6501)
# Coordinates:
#     time                  (N_PROF) datetime64[ns] 137kB ...
#     section_id            (N_PROF) <U40 3MB ...
#     file_name             (N_PROF) <U29 2MB ...
#     latitude              (N_PROF) float64 137kB ...
#     longitude             (N_PROF) float64 137kB ...
#     pressure              (P) int64 52kB ...
# Dimensions without coordinates: N_PROF, P
# Data variables:
#     ctd_temperature_filt  (N_PROF, P) float64 892MB ...
#     ctd_salinity_filt     (N_PROF, P) float64 892MB ...
#     ctd_oxygen_filt       (N_PROF, P) float64 892MB ...

# %%
DS.ctd_temperature_filt[0:100,:].plot()
