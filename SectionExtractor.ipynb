# %% [markdown]
# # Extractor de secciones

# %% [markdown]
# El código aquí presentado busca indicar que distintas secciones tiene cada fichero, de modo que se pueda tener en cuenta las siguientes cosas:
# - Multiples secciones en un mismo fichero
# - Ficheros que pertenecen a una sección pero que en el section_id no tengan los valores que le corresponden
# La idea es con un bucle revisar uno a uno y dar un listado completo de todos las secciones por archivo

# %%
import numpy as np
import xarray as xr
import os

# %%
# Data dir
carpeta = "./Data/direct_downloads/"

# Iterate for each dir and file
for carpetas in os.listdir(carpeta):
    if not os.path.isdir(carpeta + carpetas):
        continue
    print(f'>>>> Seccion {carpetas} ')
    for archivos in os.listdir(carpeta + carpetas):
        # Print file name
        print(f'    Archivo {archivos} ')
        
        # Extract the complete path
        ruta = os.path.join(carpeta, carpetas, archivos)
        
        # Open the dataset and extract section_id values
        ds = xr.open_dataset(ruta,decode_timedelta=False)
        try:
            assert "section_id" in ds.data_vars
        except AssertionError:
            print(f'{archivos} no contiene la variable section_id')
            print('----------------------------')
            continue
        
        valores = np.unique(ds.section_id)

        
        print(f'    sections: {valores}')
        print('----------------------------')
# Out:
# >>>> Seccion S04
#     Archivo 09AR9404_1_ctd.nc
#  sections: ['AUR' 'S04' 'SR03']
# ----------------------------
#     Archivo 096U20180111_ctd.nc
#  sections: ['' '132E' 'P11S' 'S4' 'SR03']
# ----------------------------
#     Archivo 09AR20060102_ctd.nc
#  sections: ['AM_CAL' 'S04I' 'TEST']
# ----------------------------
#     Archivo 90KDIOFFE6_1_ctd.nc
#  sections: ['S04P']
# ----------------------------
#     Archivo 320620110219_ctd.nc
#  sections: ['DIPOLE' 'ERS' 'P15S' 'P16S' 'P18S' 'S04P']
# ----------------------------
#     Archivo 33RO20071215_ctd.nc
#  sections: ['P18' 'S4P' 'TAO_CA' 'TEST']
# ----------------------------
#     Archivo 49NZ20121128_ctd.nc
#  sections: ['' 'I9S' 'P14S' 'S04' 'S04I']
# ----------------------------
#     Archivo 06AQANTXIII_4_ctd.nc
#  sections: ['S04']
# ----------------------------
#     Archivo 06ANTXVI_2_ctd.nc
#  sections: ['A12' 'SR04']
# ----------------------------
#     Archivo 320620180309_ctd.nc
#  sections: ['S04P']
# ----------------------------
#     Archivo 320696_3_ctd.nc
#  sections: ['S04I']
# ----------------------------
#     Archivo 490S20190121_ctd.nc
#  sections: ['-L013' '-L016' '-L018']
# ----------------------------
#     Archivo 06MT11_5_ctd.nc
#  sections: ['A21' 'S4' 'SR02']
# ----------------------------
#     Archivo 74DI200_1_ctd.nc
#  sections: ['DIS93']
# ----------------------------
#     Archivo 490S20181205_ctd.nc
#  sections: ['-L001' '-L003' '-L007' '-L009' '-L011' '-T003' '-T005']
# ----------------------------
#     Archivo 49NZ20130106_ctd.nc
#  sections: ['S04I']
# ----------------------------
#     Archivo 06AQANTX_4_ctd.nc
#  sections: ['A12' 'SR04']
# ----------------------------
# >>>> Seccion P21
#     Archivo 318MWESTW_4_ctd.nc
#  sections: ['P21E' 'P21W']
# ----------------------------
#     Archivo 325020131025_ctd.nc
#  sections: ['EPZT' 'EXTRA']
# ----------------------------
#     Archivo 49NZ20090410_ctd.nc
#  sections: ['P21']
# ----------------------------
# >>>> Seccion P17
#     Archivo 49NZ200107_1_ctd.nc
#  sections: ['P17C' 'P17N']
# ----------------------------
#     Archivo 325021_1_ctd.nc
#  sections: ['P17N']
# ----------------------------
#     Archivo 31WTTUNES_1_ctd.nc
#  sections: ['P17C']
# ----------------------------
#     Archivo 316N138_10_ctd.nc
#  sections: ['P17E' 'P19S']
# ----------------------------
#     Archivo 49NZ20170208_ctd.nc
#  sections: ['P17E']
# ----------------------------
#     Archivo 316N138_9_ctd.nc
#  sections: ['P16A' 'P17A' 'x']
# ----------------------------
#     Archivo 31WTTUNES_2_ctd.nc
#  sections: ['P16S' 'P17S']
# ----------------------------
# >>>> Seccion P10
#     Archivo 49NZ20140709_ctd.nc
#  sections: ['P10N']
# ----------------------------
#     Archivo 49UP20140609_ctd.nc
#  sections: ['P10']
# ----------------------------
#     Archivo 49NZ20111220_ctd.nc
#  sections: ['P10']
# ----------------------------
#     Archivo 3250TN026_1_ctd.nc
#  sections: ['P10']
# ----------------------------
#     Archivo 49NZ20050525_ctd.nc
#  sections: ['P10' 'P10N']
# ----------------------------
# >>>> Seccion A05
#     Archivo 74DI20040404_ctd.nc
#  sections: ['A05']
# ----------------------------
#     Archivo 31RBOACES24N_2_ctd.nc
#  sections: ['AR01']
# ----------------------------
#     Archivo 740H20200119_ctd.nc
#  sections: ['A05']
# ----------------------------
#     Archivo 29AH20110128_ctd.nc
#  sections: ['']
# ----------------------------
#     Archivo 6_74EQ20220209_ctd.nc
#  sections: ['RAPID-East']
# ----------------------------
#     Archivo 1981_US008812.nc
#  sections: ['A05']
# ----------------------------
#     Archivo 29HE06_1_ctd.nc
#  sections: ['A05']
# ----------------------------
#     Archivo 74DI20100106_ctd.nc
#  sections: ['A05']
# ----------------------------
#     Archivo 74EQ20151206_ctd.nc
#  sections: ['A05']
# ----------------------------
# >>>> Seccion I06
#     Archivo 33RR20080204_ctd.nc
#  sections: ['I06S']
# ----------------------------
#     Archivo 35MFCIVA_1_ctd.nc
#  sections: ['I06SA']
# ----------------------------
#     Archivo 325020190403_ctd.nc
#  sections: ['I06S']
# ----------------------------
#     Archivo 35MF103_1_ctd.nc
#  sections: ['I06SB']
# ----------------------------
# >>>> Seccion A02
#     Archivo 9_06M220130509_ctd.nc
#  sections: ['A02']
# ----------------------------
#     Archivo 06MT20110624_ctd.nc
#  sections: ['A02']
# ----------------------------
#     Archivo 06MT030_2_ctd.nc
#  sections: ['A02']
# ----------------------------
#     Archivo 06MT039_3_ctd.nc
#  sections: ['A02']
# ----------------------------
#     Archivo 45CE20170427_ctd.nc
#  sections: ['A02']
# ----------------------------
# >>>> Seccion I08
#     Archivo 33RR20160208_ctd.nc
#  sections: ['I08']
# ----------------------------
#     Archivo 33RR20070204_ctd.nc
#  sections: ['I08S']
# ----------------------------
#     Archivo 325020240221_ctd.nc
#  sections: ['I08S']
# ----------------------------
#     Archivo 09AR20030103_ctd.nc
#  sections: ['I08S' 'UNK']
# ----------------------------
#     Archivo 49NZ20191205_ctd.nc
#  sections: ['I08N']
# ----------------------------
#     Archivo 316N145_7_ctd.nc
#  sections: ['I05E' 'I08N' 'TRANS']
# ----------------------------
#     Archivo 316N145_5_ctd.nc
#  sections: ['I08S' 'I09S']
# ----------------------------
# >>>> Seccion P16
#     Archivo 33RO20150410_ctd.nc
#  sections: ['P16N/1']
# ----------------------------
#     Archivo 325020080826_ctd.nc
#  sections: ['P16N']
# ----------------------------
#     Archivo 31DICGC91_2_ctd.nc
#  sections: ['P16N']
# ----------------------------
#     Archivo 320620110219_ctd.nc
#  sections: ['DIPOLE' 'ERS' 'P15S' 'P16S' 'P18S' 'S04P']
# ----------------------------
#     Archivo 31WTTUNES_3_ctd.nc
#  sections: ['P16C']
# ----------------------------
#     Archivo 325020060213_ctd.nc
#  sections: ['P16N']
# ----------------------------
#     Archivo 31WTMARAII_ctd.nc
#  sections: ['P16']
# ----------------------------
#     Archivo 320620140320_ctd.nc
#  sections: ['P16S']
# ----------------------------
#     Archivo 33RO20150525_ctd.nc
#  sections: ['P16N/2']
# ----------------------------
#     Archivo 33RR20180918_ctd.nc
#  sections: ['rr1815']
# ----------------------------
#     Archivo 316N138_9_ctd.nc
#  sections: ['P16A' 'P17A' 'x']
# ----------------------------
#     Archivo 33RR200501_ctd.nc
#  sections: ['P16S']
# ----------------------------
#     Archivo 31WTTUNES_2_ctd.nc
#  sections: ['P16S' 'P17S']
# ----------------------------
# >>>> Seccion P18
#     Archivo 320620110219_ctd.nc
#  sections: ['DIPOLE' 'ERS' 'P15S' 'P16S' 'P18S' 'S04P']
# ----------------------------
#     Archivo 33RO20071215_ctd.nc
#  sections: ['P18' 'S4P' 'TAO_CA' 'TEST']
# ----------------------------
#     Archivo 33RO20161119_ctd.nc
#  sections: ['P18']
# ----------------------------
#     Archivo 31DSCG94_2_ctd.nc
#  sections: ['P18N' 'P18S']
# ----------------------------
# >>>> Seccion A10
#     Archivo 740H20180228_ctd.nc
#  sections: ['A09.5_24S']
# ----------------------------
#     Archivo 49NZ200311_4_ctd.nc
#  sections: ['A10']
# ----------------------------
#     Archivo 06MT22_5_ctd.nc
#  sections: ['A10']
# ----------------------------
#     Archivo 740H20090307_ctd.nc
#  sections: ['A095']
# ----------------------------
#     Archivo 33RO20110926_ctd.nc
#  sections: ['A10']
# ----------------------------
# >>>> Seccion P02
#     Archivo 49K6KY9401_1_ctd.nc
#  sections: ['P02T']
# ----------------------------
#     Archivo 318M20130321_ctd.nc
#  sections: ['P02E' 'P02W']
# ----------------------------
#     Archivo 318M200406_ctd.nc
#  sections: ['P02']
# ----------------------------
#     Archivo 492SSY9411_1_ctd.nc
#  sections: ['P02W']
# ----------------------------
#     Archivo 33RR20220430_ctd.nc
#  sections: ['P02']
# ----------------------------
#     Archivo 33RR20220613_ctd.nc
#  sections: ['P02E']
# ----------------------------
#     Archivo 492SSY9310_1_ctd.nc
#  sections: ['P02E']
# ----------------------------
#     Archivo 49EWBO9401_1_ctd.nc
#  sections: ['P02C']
# ----------------------------
# >>>> Seccion A16
#     Archivo 33RO20230413_ctd.nc
#  sections: ['A16N']
# ----------------------------
#     Archivo 33RO200501_ctd.nc
#  sections: ['A16S']
# ----------------------------
#     Archivo 3175MB93_ctd.nc
#  sections: ['AR21b']
# ----------------------------
#     Archivo 74JC10_1_ctd.nc
#  sections: ['A23']
# ----------------------------
#     Archivo 33RO20131223_ctd.nc
#  sections: ['A16S']
# ----------------------------
#     Archivo 318MSAVE5_ctd.nc
#  sections: ['A16S']
# ----------------------------
#     Archivo 74DI233_ctd.nc
#  sections: ['AR21']
# ----------------------------
#     Archivo 33RO20130803_ctd.nc
#  sections: ['A16N']
# ----------------------------
#     Archivo 74JC19990315_ctd.nc
#  sections: ['ALBATROSS']
# ----------------------------
#     Archivo 318MHYDROS4_ctd.nc
#  sections: ['A16C']
# ----------------------------
#     Archivo 74DI20110715_ctd.nc
#  sections: ['A16N2011']
# ----------------------------
#     Archivo 33RO20230306_ctd.nc
#  sections: ['A16N']
# ----------------------------
#     Archivo 33RO200306_01_ctd.nc
#  sections: ['A16N']
# ----------------------------
#     Archivo 32OC202_1_ctd.nc
#  sections: ['A16N']
# ----------------------------
# >>>> Seccion A20
#     Archivo 316N200309_ctd.nc
#  sections: ['A20']
# ----------------------------
#     Archivo 33AT20120419_ctd.nc
#  sections: ['A20']
# ----------------------------
#     Archivo 325020210316_ctd.nc
#  sections: ['A20']
# ----------------------------
#     Archivo 316N151_3_ctd.nc
#  sections: ['A20']
# ----------------------------
# >>>> Seccion P03
#     Archivo 49UP20130619_ctd.nc
#  sections: ['P03']
# ----------------------------
#     Archivo 31TTTPS24_2_ctd.nc
#  sections: ['P03W']
# ----------------------------
#     Archivo 49UP20210719_2_ctd.nc
#  sections: ['P03']
# ----------------------------
#     Archivo 49NZ20051127_ctd.nc
#  sections: ['P03C']
# ----------------------------
#     Archivo 49NZ20051031_ctd.nc
#  sections: ['P03E']
# ----------------------------
#     Archivo 31TTTPS24_1_ctd.nc
#  sections: ['P03E']
# ----------------------------
# >>>> Seccion A13.5
#     Archivo 33RO20100308_ctd.nc
#  sections: ['A13.5']
# ----------------------------
#     Archivo 316N19831007_ctd.nc
#  sections: ['AJAX']
# ----------------------------
#     Archivo 316N19840111_ctd.nc
#  sections: ['AJAX']
# ----------------------------
#     Archivo 35A3CITHER3_2_ctd.nc
#  sections: ['A13']
# ----------------------------
# >>>> Seccion A01
#     Archivo 06MT30_3_ctd.nc
#  sections: ['A01E' 'A01W']
# ----------------------------
#     Archivo 06MT18_1_ctd.nc
#  sections: ['A01E']
# ----------------------------
#     Archivo 35PK20140515_ctd.nc
# 35PK20140515_ctd.nc no contiene la variable section_id
# ----------------------------
#     Archivo 64PE20000926_ctd.nc
#  sections: ['A1E/AR7E']
# ----------------------------
#     Archivo 18HU95011_1_ctd.nc
#  sections: ['A01W' 'AR13' 'ARO5' 'x']
# ----------------------------
#     Archivo 5_58GS20150410_ctd.nc
#  sections: ['58GS20150410;2015107']
# ----------------------------
# >>>> Seccion I05
#     Archivo 74AB29_1_ctd.nc
#  sections: ['I5']
# ----------------------------
#     Archivo 09FA20000926_ctd.nc
#  sections: ['I02']
# ----------------------------
#     Archivo 33RR20230722_ctd.nc
#  sections: ['I05']
# ----------------------------
#     Archivo 316N145_7_ctd.nc
#  sections: ['I05E' 'I08N' 'TRANS']
# ----------------------------
#     Archivo 33RR20090320_ctd.nc
#  sections: ['I05']
# ----------------------------
#     Archivo 74AB20020301_ctd.nc
#  sections: ['I05']
# ----------------------------
#     Archivo 316N145_9_ctd.nc
#  sections: ['I04' 'I05W' 'I07C' 'TRNS1' 'TRNS2']
# ----------------------------
# >>>> Seccion P14
#     Archivo 49NZ20121128_ctd.nc
#  sections: ['' 'I9S' 'P14S' 'S04' 'S04I']
# ----------------------------
#     Archivo 49MR0706_1_ctd.nc
#  sections: ['P01' 'P14N']
# ----------------------------
#     Archivo 49NZ20071122_ctd.nc
#  sections: ['P14C' 'P14N']
# ----------------------------
#     Archivo 325023_1_ctd.nc
#  sections: ['P14N']
# ----------------------------
#     Archivo 31DSCG96_1_ctd.nc
#  sections: ['P14S' 'P15S']
# ----------------------------
#     Archivo 49NZ20231006_ctd.nc
#  sections: ['P14']
# ----------------------------
#     Archivo 316N138_7_ctd.nc
#  sections: ['P14C']
# ----------------------------
# >>>> Seccion I04
#     Archivo 49NZ200312_5_ctd.nc
#  sections: ['I03' 'I04']
# ----------------------------
#     Archivo 316N145_9_ctd.nc
#  sections: ['I04' 'I05W' 'I07C' 'TRNS1' 'TRNS2']
# ----------------------------
# >>>> Seccion I03
#     Archivo 316N145_8_ctd.nc
#  sections: ['I03']
# ----------------------------
#     Archivo 49NZ200312_5_ctd.nc
#  sections: ['I03' 'I04']
# ----------------------------
# >>>> Seccion SR03
#     Archivo 09AR9404_1_ctd.nc
#  sections: ['AUR' 'S04' 'SR03']
# ----------------------------
#     Archivo 096U20180111_ctd.nc
#  sections: ['' '132E' 'P11S' 'S4' 'SR03']
# ----------------------------
#     Archivo 09AR9309_1_ctd.nc
#  sections: ['PR12']
# ----------------------------
#     Archivo 09AR20080322_ctd.nc
#  sections: ['SR03']
# ----------------------------
#     Archivo 09AR20071216_ctd.nc
#  sections: ['' 'SR03']
# ----------------------------
#     Archivo 09AR9604_1_ctd.nc
#  sections: ['AURORA96' 'SR03']
# ----------------------------
#     Archivo 320620170410_ctd.nc
#  sections: ['SR03']
# ----------------------------
#     Archivo 09AR9501_1_ctd.nc
#  sections: ['AU95' 'SR03']
# ----------------------------
#     Archivo 09AR9601_1_ctd.nc
#  sections: ['AURORA96' 'SR03']
# ----------------------------
#     Archivo 09AR20110104_ctd.nc
#  sections: ['' 'P11' 'S4' 'SR03']
# ----------------------------
#     Archivo 09AR20011029_ctd.nc
#  sections: ['SR03' 'UNK']
# ----------------------------
#     Archivo 09AR9407_1_ctd.nc
#  sections: ['Aurora94' 'PR12']
# ----------------------------
#     Archivo 09AR9101_1_ctd.nc
#  sections: ['SR03']
# ----------------------------
# >>>> Seccion P15
#     Archivo 320620110219_ctd.nc
#  sections: ['DIPOLE' 'ERS' 'P15S' 'P16S' 'P18S' 'S04P']
# ----------------------------
#     Archivo 09SS20090203_ctd.nc
#  sections: ['P15']
# ----------------------------
#     Archivo 09FA20010524_ctd.nc
#  sections: ['P15S']
# ----------------------------
#     Archivo 3175CG90_1_ctd.nc
#  sections: ['P15S']
# ----------------------------
#     Archivo 096U20160426_ctd.nc
#  sections: ['P15S']
# ----------------------------
#     Archivo 31DSCG96_1_ctd.nc
#  sections: ['P14S' 'P15S']
# ----------------------------
#     Archivo 18DD9403_2_ctd.nc
#  sections: ['P15N']
# ----------------------------
# >>>> Seccion P01
#     Archivo 49KA199905_1_ctd.nc
#  sections: ['P1W']
# ----------------------------
#     Archivo 49NZ199905_1_ctd.nc
#  sections: ['P1C']
# ----------------------------
#     Archivo 18DD199905_1_ctd.nc
#  sections: ['P01E']
# ----------------------------
#     Archivo 49NZ20140717_ctd.nc
#  sections: ['P01' 'PAPA']
# ----------------------------
#     Archivo 49NZ20210713_ctd.nc
#  sections: ['P01']
# ----------------------------
#     Archivo 49MR0706_1_ctd.nc
#  sections: ['P01' 'P14N']
# ----------------------------
#     Archivo 90BM9316_1_ctd.nc
#  sections: ['P01W']
# ----------------------------
#     Archivo 49NZ20070724_ctd.nc
#  sections: ['P01']
# ----------------------------
#     Archivo 31TTTPS47_ctd.nc
#  sections: ['P01']
# ----------------------------
#     Archivo 49UP20110515_ctd.nc
#  sections: ['KSE' 'P01' 'P13']
# ----------------------------
# >>>> Seccion P06
#     Archivo 318M20100105_ctd.nc
#  sections: ['P06']
# ----------------------------
#     Archivo 49NZ200309_2_ctd.nc
#  sections: ['P06E']
# ----------------------------
#     Archivo 320620170820_ctd.nc
#  sections: ['P06E']
# ----------------------------
#     Archivo 320620170703_ctd.nc
#  sections: ['P06W']
# ----------------------------
#     Archivo 318M20091121_ctd.nc
#  sections: ['P06']
# ----------------------------
#     Archivo 316N138_4_ctd.nc
#  sections: ['P06C']
# ----------------------------
#     Archivo 316N138_3_ctd.nc
#  sections: ['P06E']
# ----------------------------
#     Archivo 316N138_5_ctd.nc
#  sections: ['P06W']
# ----------------------------
#     Archivo 49NZ200308_ctd.nc
#  sections: ['P06']
# ----------------------------
# >>>> Seccion A22
#     Archivo 325020210420_ctd.nc
#  sections: ['A22']
# ----------------------------
#     Archivo 33AT20120324_ctd.nc
#  sections: ['A22']
# ----------------------------
#     Archivo 316N200310_ctd.nc
#  sections: ['A22']
# ----------------------------
#     Archivo 316N151_4_ctd.nc
#  sections: ['A22']
# ----------------------------
# >>>> Seccion A12
#     Archivo 06AQ20080210_ctd.nc
# 06AQ20080210_ctd.nc no contiene la variable section_id
# ----------------------------
#     Archivo 06AQ200211_2_ctd.nc
#  sections: ['A12']
# ----------------------------
#     Archivo 06AQ19941123_ctd.nc
#  sections: ['ANT-XII/2 (PS33)']
# ----------------------------
#     Archivo 06AQ20141202_ctd.nc
#  sections: ['PS89,A12,ANTXXX_2']
# ----------------------------
#     Archivo 35MF20080207_ctd.nc
# 35MF20080207_ctd.nc no contiene la variable section_id
# ----------------------------
#     Archivo 06AQ20060825_ctd.nc
#  sections: ['ANT-XXIII/7']
# ----------------------------
#     Archivo None_ctd.nc
#  sections: ['ANT-V/2 (PS10)']
# ----------------------------
#     Archivo 06ANTXVI_2_ctd.nc
#  sections: ['A12' 'SR04']
# ----------------------------
#     Archivo 06AQ20071128_ctd.nc
#  sections: ['A12']
# ----------------------------
#     Archivo 06ANTXVIII_3_ctd.nc
#  sections: ['A12']
# ----------------------------
#     Archivo 06AQ20050122_ctd.nc
#  sections: ['A12']
# ----------------------------
#     Archivo 06AQANTX_4_ctd.nc
#  sections: ['A12' 'SR04']
# ----------------------------
# >>>> Seccion I09S
#     Archivo 49NZ20121128_ctd.nc
#  sections: ['' 'I9S' 'P14S' 'S04' 'S04I']
# ----------------------------
#     Archivo 09AR20041223_ctd.nc
#  sections: ['I09S' 'PET' 'PULSE' 'TEST']
# ----------------------------
#     Archivo 09AR20120105_ctd.nc
#  sections: ['' 'I09S']
# ----------------------------
#     Archivo 096U20240101_ctd.nc
#  sections: ['I09S']
# ----------------------------
#     Archivo 316N145_5_ctd.nc
#  sections: ['I08S' 'I09S']
# ----------------------------
